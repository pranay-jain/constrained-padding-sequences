# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os 
import csv
from math import log2


sys.path.insert(0, '..')
os.chdir('..')
print(os.getcwd())

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/andrew/constrained-padding-sequences

# %%
from precision_recall import precision_recall_autcomplete, precision_recall_wiki, precision_recall_linode_from_index, compute_precision_recall_ldiv_pad_scheme

from pwod import run_pwod
from pfs import run_pfs
from mvmd import run_mvmd
from bdk import run_bdk

# %% [markdown]
# ### Plotting Code

# %%
mp_keys = ['\\noDistAlg (\\padFactor=1.25)', '\\ourAlg (\\padFactor=1.25)', '\\lDivAlg{3}', '\\bdkAlg']

# %%
style_dict = {}                # (style, color, marker)

style_dict['\\noDistAlg (\\padFactor=1.25)']    = ('dashed', 'darkgrey', 'o')
style_dict['\\ourAlg (\\padFactor=1.25)']             = ('solid', 'black', 'D')
style_dict['\\lDivAlg{3}']    = ('dashdot', '#047495', 'x')
style_dict['\\bdkAlg']                    = ('dotted', 'blue', 'o')

# %%
def plot_precision_recall(plot_mp):
    f, ax = plt.subplots()
    ax.set_xlim(left=0)
    ax.set_xlim(right=1)
    ax.set_ylim(bottom=0)
    ax.set_ylim(top=1)

    # plot_mp = { k:v for k, v in mp.items() if k in mp_keys }

    for method, precision_recall_map in plot_mp.items():
        ax.plot(
            list(precision_recall_map.keys()),
            list(precision_recall_map.values()),
            label=method,
            linestyle=style_dict[method][0],
            color=style_dict[method][1],
            marker=style_dict[method][2],
            linewidth=2)

    plt.xlabel('Recall', fontsize=16)
    plt.ylabel('Precision', fontsize=16)
    # plt.title(f'Target Set: Words of Length {seq_len}')
    # plt.legend()

    major_ticks = np.arange(0, 1.1, 0.2)
    minor_ticks = np.arange(0, 1.1, 0.1)

    ax.set_xticks(major_ticks)
    ax.set_xticks(minor_ticks, minor=True)
    ax.set_yticks(major_ticks)
    ax.set_yticks(minor_ticks, minor=True)

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # And a corresponding grid
    plt.grid(which='both', alpha=1, linestyle='dotted')

    legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=len(ax.lines))

    plt.show()

# %% [markdown]
# ### Autocomplete Dataset

# %%
dataset = 'autocomplete'
c = 1.25
l = 3

plot_mp = {}

pad_scheme_pwod, _ = run_pwod(dataset, c)
pad_scheme_pfs = run_pfs(dataset, c)['pad_scheme']

pad_scheme_bdk, _, _, _, _, _ = run_bdk(dataset, num_trials=1000)

pad_scheme_mvmd = run_mvmd(dataset, l)['pad_scheme']

pad_scheme_bdk_flat = {k: v[0][0] for k,v in pad_scheme_bdk.items()}
pad_scheme_flat_pwod = {k: v[0][0] for k, v in pad_scheme_pwod.items() }
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-28
# Gurobi's optimization method runtime (in seconds): 39.05308985710144
# Completed BDK Run 0
# Completed BDK Run 1
# Completed BDK Run 2
# Completed BDK Run 3
# Completed BDK Run 4
# Completed BDK Run 5
# Completed BDK Run 6
# Completed BDK Run 7
# Completed BDK Run 8
# Completed BDK Run 9
# Completed BDK Run 10
# Completed BDK Run 11
# Completed BDK Run 12
# Completed BDK Run 13
# Completed BDK Run 14
# Completed BDK Run 15
# Completed BDK Run 16
# Completed BDK Run 17
# Completed BDK Run 18
# Completed BDK Run 19
# Completed BDK Run 20
# Completed BDK Run 21
# Completed BDK Run 22
# Completed BDK Run 23
# Completed BDK Run 24
# Completed BDK Run 25
# Completed BDK Run 26
# Completed BDK Run 27
# Completed BDK Run 28
# Completed BDK Run 29
# Completed BDK Run 30
# Completed BDK Run 31
# Completed BDK Run 32
# Completed BDK Run 33
# Completed BDK Run 34
# Completed BDK Run 35
# Completed BDK Run 36
# Completed BDK Run 37
# Completed BDK Run 38
# Completed BDK Run 39
# Completed BDK Run 40
# Completed BDK Run 41
# Completed BDK Run 42
# Completed BDK Run 43
# Completed BDK Run 44
# Completed BDK Run 45
# Completed BDK Run 46
# Completed BDK Run 47
# Completed BDK Run 48
# Completed BDK Run 49
# Completed BDK Run 50
# Completed BDK Run 51
# Completed BDK Run 52
# Completed BDK Run 53
# Completed BDK Run 54
# Completed BDK Run 55
# Completed BDK Run 56
# Completed BDK Run 57
# Completed BDK Run 58
# Completed BDK Run 59
# Completed BDK Run 60
# Completed BDK Run 61
# Completed BDK Run 62
# Completed BDK Run 63
# Completed BDK Run 64
# Completed BDK Run 65
# Completed BDK Run 66
# Completed BDK Run 67
# Completed BDK Run 68
# Completed BDK Run 69
# Completed BDK Run 70
# Completed BDK Run 71
# Completed BDK Run 72
# Completed BDK Run 73
# Completed BDK Run 74
# Completed BDK Run 75
# Completed BDK Run 76
# Completed BDK Run 77
# Completed BDK Run 78
# Completed BDK Run 79
# Completed BDK Run 80
# Completed BDK Run 81
# Completed BDK Run 82
# Completed BDK Run 83
# Completed BDK Run 84
# Completed BDK Run 85
# Completed BDK Run 86
# Completed BDK Run 87
# Completed BDK Run 88
# Completed BDK Run 89
# Completed BDK Run 90
# Completed BDK Run 91
# Completed BDK Run 92
# Completed BDK Run 93
# Completed BDK Run 94
# Completed BDK Run 95
# Completed BDK Run 96
# Completed BDK Run 97
# Completed BDK Run 98
# Completed BDK Run 99
# Completed BDK Run 100
# Completed BDK Run 101
# Completed BDK Run 102
# Completed BDK Run 103
# Completed BDK Run 104
# Completed BDK Run 105
# Completed BDK Run 106
# Completed BDK Run 107
# Completed BDK Run 108
# Completed BDK Run 109
# Completed BDK Run 110
# Completed BDK Run 111
# Completed BDK Run 112
# Completed BDK Run 113
# Completed BDK Run 114
# Completed BDK Run 115
# Completed BDK Run 116
# Completed BDK Run 117
# Completed BDK Run 118
# Completed BDK Run 119
# Completed BDK Run 120
# Completed BDK Run 121
# Completed BDK Run 122
# Completed BDK Run 123
# Completed BDK Run 124
# Completed BDK Run 125
# Completed BDK Run 126
# Completed BDK Run 127
# Completed BDK Run 128
# Completed BDK Run 129
# Completed BDK Run 130
# Completed BDK Run 131
# Completed BDK Run 132
# Completed BDK Run 133
# Completed BDK Run 134
# Completed BDK Run 135
# Completed BDK Run 136
# Completed BDK Run 137
# Completed BDK Run 138
# Completed BDK Run 139
# Completed BDK Run 140
# Completed BDK Run 141
# Completed BDK Run 142
# Completed BDK Run 143
# Completed BDK Run 144
# Completed BDK Run 145
# Completed BDK Run 146
# Completed BDK Run 147
# Completed BDK Run 148
# Completed BDK Run 149
# Completed BDK Run 150
# Completed BDK Run 151
# Completed BDK Run 152
# Completed BDK Run 153
# Completed BDK Run 154
# Completed BDK Run 155
# Completed BDK Run 156
# Completed BDK Run 157
# Completed BDK Run 158
# Completed BDK Run 159
# Completed BDK Run 160
# Completed BDK Run 161
# Completed BDK Run 162
# Completed BDK Run 163
# Completed BDK Run 164
# Completed BDK Run 165
# Completed BDK Run 166
# Completed BDK Run 167
# Completed BDK Run 168
# Completed BDK Run 169
# Completed BDK Run 170
# Completed BDK Run 171
# Completed BDK Run 172
# Completed BDK Run 173

# %%
seq_len = 7
recall_precision_mp = precision_recall_autcomplete(pad_scheme_flat_pwod, seq_len=seq_len, method=f'pwod{c}')
plot_mp['\\noDistAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = precision_recall_autcomplete(pad_scheme_pfs, seq_len=seq_len, method=f'lp-prefix(c={c})')
plot_mp['\\ourAlg (\\padFactor=1.25)'] = recall_precision_mp

l = 3
pad_scheme_mvmd = run_mvmd(dataset, l)['pad_scheme']
recall_precision_mp = compute_precision_recall_ldiv_pad_scheme(l, pad_scheme_mvmd, seq_len, dataset)
plot_mp['\\lDivAlg{3}'] = recall_precision_mp

recall_precision_mp = precision_recall_autcomplete(pad_scheme_bdk_flat, seq_len=seq_len, method='Backes, et al.')
plot_mp['\\bdkAlg'] = recall_precision_mp

plot_precision_recall(plot_mp)

# %%
seq_len = 8
recall_precision_mp = precision_recall_autcomplete(pad_scheme_flat_pwod, seq_len=seq_len, method=f'pwod{c}')
plot_mp['\\noDistAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = precision_recall_autcomplete(pad_scheme_pfs, seq_len=seq_len, method=f'lp-prefix(c={c})')
plot_mp['\\ourAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = compute_precision_recall_ldiv_pad_scheme(l, pad_scheme_mvmd, seq_len, dataset)
plot_mp['\\lDivAlg{3}'] = recall_precision_mp

recall_precision_mp = precision_recall_autcomplete(pad_scheme_bdk_flat, seq_len=seq_len, method='Backes, et al.')
plot_mp['\\bdkAlg'] = recall_precision_mp

plot_precision_recall(plot_mp)

# %%
seq_len = 9
recall_precision_mp = precision_recall_autcomplete(pad_scheme_flat_pwod, seq_len=seq_len, method=f'pwod{c}')
plot_mp['\\noDistAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = precision_recall_autcomplete(pad_scheme_pfs, seq_len=seq_len, method=f'lp-prefix(c={c})')
plot_mp['\\ourAlg (\\padFactor=1.25)'] = recall_precision_mp

l = 3
pad_scheme_mvmd = run_mvmd(dataset, l)['pad_scheme']
recall_precision_mp = compute_precision_recall_ldiv_pad_scheme(l, pad_scheme_mvmd, seq_len, dataset)
plot_mp['\\lDivAlg{3}'] = recall_precision_mp

recall_precision_mp = precision_recall_autcomplete(pad_scheme_bdk_flat, seq_len=seq_len, method='Backes, et al.')
plot_mp['\\bdkAlg'] = recall_precision_mp

plot_precision_recall(plot_mp)

# %% [markdown]
# ### Linode from Index dataset

# %%
dataset = 'linode_from_index'
c = 1.25
l = 3

plot_mp = {}

pad_scheme_pwod, _ = run_pwod(dataset, c)
pad_scheme_pfs = run_pfs(dataset, c)['pad_scheme']

pad_scheme_bdk, _, _, _, _, _ = run_bdk(dataset, num_trials=10)

pad_scheme_mvmd = run_mvmd(dataset, l)['pad_scheme']

pad_scheme_bdk_flat = {k: v[0][0] for k,v in pad_scheme_bdk.items()}
pad_scheme_flat_pwod = {k: v[0][0] for k, v in pad_scheme_pwod.items() }

# %%
seq_len = 3
recall_precision_mp = precision_recall_linode_from_index(pad_scheme_flat_pwod, seq_len=seq_len, method=f'pwod{c}')
plot_mp['\\noDistAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = precision_recall_linode_from_index(pad_scheme_pfs, seq_len=seq_len, method=f'lp-prefix(c={c})')
plot_mp['\\ourAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = compute_precision_recall_ldiv_pad_scheme(l, pad_scheme_mvmd, seq_len, dataset)
plot_mp['\\lDivAlg{3}'] = recall_precision_mp

recall_precision_mp = precision_recall_linode_from_index(pad_scheme_bdk_flat, seq_len=seq_len, method='Backes, et al.')
plot_mp['\\bdkAlg'] = recall_precision_mp

plot_precision_recall(plot_mp)

# %% [markdown]
# ### Wikipedia Dataset

# %%
dataset = 'wikipedia'
c = 2
l = 3

plot_mp = {}

pad_scheme_pwod, _ = run_pwod(dataset, c)
pad_scheme_pfs = run_pfs(dataset, c)['pad_scheme']

pad_scheme_bdk, _, _, _, _, _ = run_bdk(dataset, num_trials=10)

pad_scheme_mvmd = run_mvmd(dataset, l)['pad_scheme']

pad_scheme_bdk_flat = {k: v[0][0] for k,v in pad_scheme_bdk.items()}
pad_scheme_flat_pwod = {k: v[0][0] for k, v in pad_scheme_pwod.items() }

# %%
seq_len = 7
recall_precision_mp = precision_recall_wiki(pad_scheme_flat_pwod, seq_len=seq_len, method=f'pwod{c}')
plot_mp['\\noDistAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = precision_recall_wiki(pad_scheme_pfs, seq_len=seq_len, method=f'lp-prefix(c={c})')
plot_mp['\\ourAlg (\\padFactor=1.25)'] = recall_precision_mp

recall_precision_mp = compute_precision_recall_ldiv_pad_scheme(l, pad_scheme_mvmd, seq_len, dataset)
plot_mp['\\lDivAlg{3}'] = recall_precision_mp

recall_precision_mp = precision_recall_wiki(pad_scheme_bdk_flat, seq_len=seq_len, method='Backes, et al.')
plot_mp['\\bdkAlg'] = recall_precision_mp

plot_precision_recall(plot_mp)
